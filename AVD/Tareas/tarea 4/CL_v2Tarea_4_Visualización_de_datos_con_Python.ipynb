# %% [markdown]
# <img src = "https://drive.google.com/uc?export=view&id=1rSrsZ04aJ_D3BC67Cy2dBUZ6tmguydNf" alt = "Encabezado MLDS" width = "100%">  </img>

# %% [markdown]
# #**Tarea 4 : Visualización de datos con *Python***
# ---
#
# Esta es una tarea para practicar las habilidades adquiridas usando *Matplotlib* y *Seaborn* en la construcción de visualizaciones de información. Utilizaremos el *dataset* de  ***games_review***, el cual contiene la información sobre la aceptación de 50000 diferentes videojuegos disponibles en la plataforma *STEAM*. Este conjunto de datos puede consultarlo en la plataforma [Kaggle](https://www.kaggle.com/datasets/antonkozyriev/game-recommendations-on-steam). El data set que utilizaremos es uno al que hemos hecho algunos cambios.
#
# El conjunto de datos cuenta con las siguientes variables:
#
# | Variable | Definición	|
# | --- | --- |
# | title| Titulo del juego |
# | rating| Puntaje asignado por el público |
# | positive_ratio| Tasa de comentarios positivos |
# | user_reviews| Número de comentarios |
# | price_original| Precio del videojuego |
# | discount| Descuento asignado en la plataforma |
# | platform| Sistema operativo donde ejecutar el juego |
# | year_release| Año de salida del título |
#
#
# En esta tarea usted deberá recrear algunas visualizaciones de ejemplo usando *Python* y sus librerías de visualización presentadas esta semana. Recuerde almacenar en una variable el objeto retornado por la función para la correcta calificación.
#
# > **Nota:** Esta tarea va a ser calificada estableciendo una conexión con **[UNCode](https://juezun.github.io/)**. La conexión se realizará al ejecutar la celda indicada e ingresando los datos de usuariio.En cada ejercicio se indicará si es calificable o no, también los lugares donde debe escribir su código sin modificar lo demás con un aproximado de cantidad de líneas a escribir. No se preocupe si su código toma más líneas, esto es simplemente un aproximado destinado a que pueda replantear su estrategia si el código está tomando más de las esperadas. No es un requisito estricto y soluciones más largas también son válidas.
#
# >**La tarea es incremental, es recomendable resolver los puntos en orden.**
#
# >En caso de tener dudas de cómo solucionar este tipo de ejercicios, por favor consultar el demo en la unidad 0

# %% [markdown]
# Ejecute la siguiente celda para importar las librerías.

# %%
#Importar librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.dpi'] = 110

# %%
#TEST_CELL
# !python --version
print('NumPy', np.__version__)
print('Pandas', pd.__version__)
print('Matplotlib', mpl.__version__)
print('Seaborn', sns.__version__)
# Out:
# Python 3.12.12
# NumPy 2.0.2
# Pandas 2.2.2
# Matplotlib 3.10.0
# Seaborn 0.13.2

# %% [markdown]
# Este material fue realizado con las siguientes versiones:
#
# - Python 3.12.11
#
# - NumPy 2.0.2
#
# - Pandas 2.2.2
#
# - Matplotlib 3.10.0
#
# - Seaborn 0.13.2

# %% [markdown]
# ## **Conexión UNCode**

# %%
# %%capture
# !pip install rlxcrypt
# !wget --no-cache -O session.pye -q https://raw.githubusercontent.com/JuezUN/INGInious/master/external%20libs/session.pye

# %%
import rlxcrypt
import session

grader = session.LoginSequence("AYVDD-GroupMLDS-1-2026-1@b7cad3df-1c49-4211-9c11-5014cdabbbf0")
# Out:
#     <div>
#     <div style="display: flex">
#         <div style="padding: 10px">
#           <img
#             src="https://uncode.unal.edu.co/static/images/logo_unc.svg"
#             width="50px"
#             height="50px"
#           />
#         </div>
#
#         <div>
#           <h2>UNCode Notebooks grader API</h2>
#           <hr />
#         </div>
#       </div>
#
#       <div style="display: flex">
#         <span>Please enter authentication data</span>
#       </div>
#     </div>
# <h5 style="color: green"><Response [200]></h5>
# <h5 style="color: green">Auth process succeeded</h5>
# <h5>View your courses <a href="https://uncode.unal.edu.co/courselist">at UNCode platform</a></h5>
# <h3>You will sumbit code to course: <span style="color: green">Análisis y visualización de datos | Grupo MLDS-1 | 2026 - 1<span></h3>
# <h3>You will sumbit code to task: <span style="color: blue">CL Tarea 4 - Visualización de datos<span></h3>

# %% [markdown]
# ## **0.  Leer el archivo de datos**
# ---
# En esta ocasión importaremos el archivo de datos aprovechando la utilidad de carga de conjuntos de datos comunes de *Seaborn*.
# Puede descargar e importar el archivo, como se detalla a continuación, o ejecutar el siguiente código.

# %% [markdown]
#   1. Por favor descargue el archivo con el conjunto de datos desde el siguiente enlace: **[games_clean.csv](https://raw.githubusercontent.com/mindlab-unal/mlds1-datasets/refs/heads/main/actividades/games_clean.csv)**.
#
#   2. En el enlace, haga clic derecho y seleccione la opción **"Guardar como..."**.
#
#   3. Cargue este archivo en su sistema de archivos de **Google Colaboratory**. Para hacer esto:
#
# * Haga clic donde aparece el icono del directorio en la parte izquierda de la ventana en *Google Colaboratory* (resaltado en azul en la siguiente imagen con el número 1).
# * Después, haga clic en el icono **"Subir"** (resaltado en azul en la siguiente imagen con el número 2).
# * Seleccione el archivo **`games_clean.csv`** que previamente descargó y haga clic en **"Aceptar"**.
#
# <img src = "https://drive.google.com/uc?export=view&id=13W59jfdOpAn_DYIjpXt4WPBZiU7BlRGY" alt = "Sistema archivos colab" width = "70%">  </img>
#
# 4. Ejecute la siguiente celda para cargar el conjunto de datos dentro del DataFrame de *pandas* llamado **`games_clean.csv`**:

# %%
# !wget https://raw.githubusercontent.com/mindlab-unal/mlds1-datasets/refs/heads/main/actividades/games_clean.csv
# Out:
# --2026-02-21 23:13:11--  https://raw.githubusercontent.com/mindlab-unal/mlds1-datasets/refs/heads/main/actividades/games_clean.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2888402 (2.8M) [text/plain]
# Saving to: ‘games_clean.csv.1’
#
# games_clean.csv.1   100%[===================>]   2.75M  --.-KB/s    in 0.07s
#
# 2026-02-21 23:13:11 (41.8 MB/s) - ‘games_clean.csv.1’ saved [2888402/2888402]

# %%
# Creando los datos  (EJECUTE ESTA CELDA SIN MODIFICARLA)
games = pd.read_csv('games_clean.csv')
games.head()
# Out:
#                                title    rating  positive_ratio  user_reviews  \
# 0  Prince of Persia: Warrior Within™  Positive              84          2199
# 1            BRINK: Agents of Change  Positive              85            21
# 2       Monaco: What's Yours Is Mine  Positive              92          3722
# 3                 Escape Dead Island     Mixed              61           873
# 4            Dungeon of the ENDLESS™  Positive              88          8784
#
#    price_original  discount  year_release platform
# 0            9.99       0.0          2008      win
# 1            2.99       0.0          2011      win
# 2           14.99       0.0          2013    linux
# 3           14.99       0.0          2014      win
# 4           11.99       0.0          2014      mac

# %%
#TEST_CELL
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50872 entries, 0 to 50871
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           50872 non-null  object
#  1   rating          50872 non-null  object
#  2   positive_ratio  50872 non-null  int64
#  3   user_reviews    50872 non-null  int64
#  4   price_original  50872 non-null  float64
#  5   discount        50872 non-null  float64
#  6   year_release    50872 non-null  int64
#  7   platform        50872 non-null  object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 3.1+ MB

# %% [markdown]
# En los siguientes ejercicios deberá replicar las figuras que se presentan a continuación usando las librerías mencionadas. No se preocupe por replicar exactamente los mismos colores, sino las figuras como tal. La mayoría de figuras se puede recrear usando solamente una o dos líneas de código. Preste especial atención a las etiquetas $x$ y $y$ de los ejes pues no se le brindará mucha más información.

# %%
sns.set_style('whitegrid') #Se usará este estilo en los casos de ejemplo que utilicen Seaborn.

# %% [markdown]
# ## **1. Correlación entre variables numéricas**
# ---
#
# El primer paso en el análisis de datos es evaluar la **correlación entre las variables numéricas** del *dataset*. Para ello, no solo calcularemos la **matriz de correlación lineal**, sino que también **visualizaremos un mapa de calor** para interpretar los resultados de manera más clara.
#
# En este ejercicio, deberás **recrear el mapa de calor** mostrado en la referencia utilizando la librería **Seaborn**.
#
# > Para la imagen de referencia, utilizamos el *colormap* **`coolwarm`**.
#
# Finalmente, almacena el resultado de la función de visualización en la variable **`games_corr_matrix`**.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pistas</b></font>
# </summary>
#
# * Para este ejercicio deberá utilizar conceptos usados en las unidades anteriores. Primero es necesario calcular la matriz de correlación y después graficar el mapa de calor.
# * Tenga presente la documentación de las funciones de visualización. Según la función que utilice, los argumentos a utilizar para definir los parámetros podrían variar.
# * Deberá agregar el título de la gráfica por su cuenta. Para esto, utilice métodos de objetos **`Axes`** de *Matplotlib* como **`set_title`** sobre el objeto **`corr_matrix`**.
#
# * La cadena de texto exacta usada en este ejercicio es:
#   * **Título**: `'Correlation heatmap'`

# %%
### ESCRIBA SU CÓDIGO AQUÍ ### (~ 1-3 líneas de código)

datos_correlacion = games.drop(columns=['title', 'rating', 'platform']).corr()
games_corr_matrix = sns.heatmap(datos_correlacion, annot=True, cmap='coolwarm', vmin=datos_correlacion.values.min(), vmax=1)
games_corr_matrix.set_title('Correlation heatmap')
### FIN DEL CÓDIGO ###
games_corr_matrix
# Out:
# <Axes: title={'center': 'Correlation heatmap'}>

# %% [markdown]
# **Salida esperada:**
#
# <img src = "https://drive.google.com/uc?export=view&id=1hAat_2si1W7dXU5ee5w9iaOdO3KZmtB3" alt = "Encabezado MLDS" width = "70%">  </img>

# %%
# NO ELIMINAR - NECESARIO PARA LA CORRECTA CALIFICACIÓN
games_corr_matrix.get_figure().show()
plt.close()

# %% [markdown]
# ### **Evaluar código**

# %%
grader.run_test("Test 1_1", globals())
# Out:
# Test 1_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 1_2", globals())
# Out:
# Test 1_2
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %% [markdown]
# ## **2. Precio de los videojuegos**
# ---
#
# Vamos a explorar los precios de los videojuegos.  Recuerde considerar el descuento aplicado.

# %% [markdown]
# ### **2.1. Distribución del precio**
# ---
#
# En esta sección, representarás gráficamente la **distribución del precio** mediante un **histograma**.
#
# - Utiliza el color **naranja** (**`orange`**) para la gráfica.
# - Divide el rango de precios en **100 intervalos de clase** (**`bins=100`**).
#
# Finalmente, almacena el resultado de la función de visualización en la variable **`dist_precio`**.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pistas</b></font>
# </summary>
#
# * Deberá seleccionar los datos del precio (**`price_original`**) y calcular el valor final a partir del descuento.
# * Después representé su distribución por medio de un histograma usando *Seaborn* o *Matplotlib*.
# * Tenga presente la documentación de las funciones de visualización.
# * En este ejercicio **SÍ** se evaluará el color de la figura. Utilice el nombre del color **`orange`**.
# * Deberá agregar el título y etiquetas de los ejes por su cuenta. Para esto, utilice métodos de objetos **`Axes`** de *Matplotlib* como **`set_title`** y **`set_xlabel`** sobre el objeto **`dist_precio`**.
# * Las cadenas de texto exactas usadas en este ejercicio son:
#   * **Título**: `'price distribution'`
#   * **Etiqueta del eje X**: `'price'`
#   * **Etiqueta del eje Y**: `'title count'`

# %%
games['price'] = games['price_original'] * (1 - games['discount'] / 100)

# %%
### ESCRIBA SU CÓDIGO AQUÍ ### (~ 4-8 líneas de código)
dist_precio = sns.histplot(games['price'], bins=100,color='orange')
dist_precio.set_title('price distribution')
dist_precio.set_xlabel('price')
dist_precio.set_ylabel('title count')
### FIN DEL CÓDIGO ###
dist_precio
# Out:
# <Axes: title={'center': 'price distribution'}, xlabel='price', ylabel='title count'>

# %% [markdown]
# **Salida esperada:**
#
# <img src = "https://drive.google.com/uc?export=view&id=1gt9mDdwbQ2ew-xm2GTMP1lO0vkxQxZgL" alt = "Encabezado MLDS" width = "70%">  </img>

# %%
# NO ELIMINAR - NECESARIO PARA LA CORRECTA CALIFICACIÓN
dist_precio.get_figure().show()
plt.close()

# %%
dist_precio.axes.patches
# Out:
# <Axes.ArtistList of 100 patches>

# %% [markdown]
# ### **Evaluar código**

# %%
grader.run_test("Test 2_1_1", globals())
# Out:
# Test 2_1_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 2_1_2", globals())
# Out:
# Test 2_1_2
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %% [markdown]
# ### **2.2. Descuento y aceptación**
# ---
#
# Considerando que algunos títulos no tienen la aceptación esperada, se espera que tengan un mayor descuento. ¿Es este el caso?
#
# En esta tarea deberá representar gráficamente la relación entre el descuento (`discount`) y la aceptación (`positive_ratio`) como se presenta a continuación.
#
# > Esta vez no se personalizaron los estilos de la gráfica con la ayuda de sus argumentos.
#
# Almacene el resultado de la función de visualización en la variable **`descuento_aceptacion`**.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pistas</b></font>
# </summary>
# <p>
#
# * Construya el gráfico de distribuciones conjuntas de *Seaborn*
# * Para este ejercicio no debe hacer ninguna modificación especial. Es suficiente con identificar la función de visualización apropiada y usar los argumentos de datos correctos.
#
#
# </p>

# %%
### ESCRIBA SU CÓDIGO AQUÍ ### (~ 1 línea de código)
descuento_aceptacion = sns.jointplot(x='discount', y='positive_ratio', data=games)
### FIN DEL CÓDIGO ###

descuento_aceptacion

# %% [markdown]
# **Salida esperada:**
#
# <img src = "https://drive.google.com/uc?export=view&id=1KG-DnidU-NkJz1LzXQ7_vXgEfC383jGc" alt = "Encabezado MLDS" width = "70%">  </img>

# %%
# NO ELIMINAR - NECESARIO PARA LA CORRECTA CALIFICACIÓN
descuento_aceptacion.fig.show()
plt.close()

# %% [markdown]
# ### **Evaluar código**

# %%
grader.run_test("Test 2_2_1", globals())
# Out:
# Test 2_2_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 2_2_2", globals())
# Out:
# Test 2_2_2
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %% [markdown]
# ## **3. windows, mac o linux**
# ---
#
# Ahora, exploraremos el precio de los títulos, distinguiéndolos por su plataforma y analizando la relación que estas variables tuvieron con su valoración.

# %% [markdown]
# ### **3.1. Distribución del precio por plataforma**
# ---
# Primero, exploraremos la distribución de los precios considerando las tres plataformas en gráficos distintos.
#
# En esta tarea deberá representar mediante tres **histogramas** los precios de los títulos en tres gráficas en la misma figura, usando para discriminar las distribuciones la plataforma (**`platform`**) como se muestra a continuación:
#
# > * Los diagramas son construidos como un **`FacetGrid`** de *Seaborn*.
# * La paleta de color usada en el ejemplo es el *colormap* **`cool`**.
#
# Almacene el resultado de la función de visualización en la variable **`price_platform_dist`**.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pistas</b></font>
# </summary>
# <p>
#
# * La solución tiene que realizarse con **`FacetGrid`** de *Seaborn* junto con la función de visualización de *Matplotlib* para graficar histogramas. No utilice el método **`displot`** ni **`histplot`** en el proceso y utilice los *bins* igual a 50
# * Para la imagen de referencia utilizamos el *colormap* **`cool`** como paleta de color. Este *colormap* se define al generar el **`FacetGrid`** vacío.
# * Para este ejercicio, tanto el color como la columna son usados para diferenciar entre las dos categorías.
# </p>

# %%
### ESCRIBA SU CÓDIGO AQUÍ ### (~ 2-3 líneas de código)
price_platform_dist = sns.FacetGrid(data=games,col='platform',palette='cool',hue='platform').map(plt.hist,'price_original', bins=50)

### FIN DEL CÓDIGO ###
price_platform_dist

# %% [markdown]
# **Salida esperada:**
#
# <img src = "https://drive.google.com/uc?export=view&id=1VImIb8Z_mgrJhpqCsoSLGHGN9R8qGg6S" alt = "Encabezado MLDS" width = "100%">  </img>

# %%
# NO ELIMINAR - NECESARIO PARA LA CORRECTA CALIFICACIÓN
price_platform_dist.fig.show()
plt.close()

# %% [markdown]
# ### **Evaluar código**

# %%
grader.run_test("Test 3_1_1", globals())
# Out:
# Test 3_1_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 3_1_2", globals())
# Out:
# Test 3_1_2
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %% [markdown]
# ### **3.2. ¿En qué SO jugar?**
# ---
# Muchos jugadores en la actualidad afirman que, si bien todos los títulos desarrollados pueden ser ejecutados en Windows, cada vez más llegan jugos AAA a sistemas operativos menos populares como macOS y GNU-linux.
#
# En esta tarea, usted debe representar gráficamente la cantidad de títulos con críticas positivas para cada plataforma. Para esto, realicé una **gráfica de barras** con el conteo de valores para cada caso, como se muestra a continuación:
#
# > Para la imagen de referencia utilizamos el *colormap*  **`plasma`** como paleta de color.
#
# Almacene el resultado de la función de visualización en la variable **`platform_games`**.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pistas</b></font>
# </summary>
#
# * Usa la función para graficar conteos de variables categóricas de *Seaborn*.
# * Deberá agregar el título y etiquetas de los ejes por su cuenta. Para esto, utilice métodos de objetos **`Axes`** de *Matplotlib* como **`set_title`** y **`set_xlabel`** sobre el objeto **`platform_games`**.
# * Las cadenas de texto exactas usadas en este ejercicio son:
#   * **Título**: `'windows vs mac vs linux'`
#   * **Etiqueta del eje X**: `'platforms'`
#   * **Etiqueta del eje Y**: `'Total titles'`

# %%
### ESCRIBA SU CÓDIGO AQUÍ ### (~ 4-5 líneas de código)
platform_games = sns.countplot(data=games, x='platform',palette='plasma', hue='rating')
platform_games.set_title('windows vs mac vs linux')
platform_games.set_xlabel('platforms')
platform_games.set_ylabel('Total titles')
### FIN DEL CÓDIGO ###
platform_games
# Out:
# <Axes: title={'center': 'windows vs mac vs linux'}, xlabel='platforms', ylabel='Total titles'>

# %% [markdown]
# **Salida esperada:**
#
# <img src = "https://drive.google.com/uc?export=view&id=1mnqc4wNe8VF2kdZJCSZzmzdkFfSkZWLF" alt = "Encabezado MLDS" width = "70%">  </img>

# %%
# NO ELIMINAR - NECESARIO PARA LA CORRECTA CALIFICACIÓN
platform_games.get_figure().show()
plt.close()

# %% [markdown]
# ### **Evaluar código**

# %%
grader.run_test("Test 3_2_1", globals())
# Out:
# Test 3_2_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 3_2_2", globals())
# Out:
# Test 3_2_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %% [markdown]
# ## **4. Número de reseñas y valoración**
# ---
#
# Un indicador que suelen usar la mayoría de los jugadores antes de adquirir un título es observar el número de reseñas postivas del juego. A continuación evaluaremos esta variable respecto a la valoración del videojuego

# %% [markdown]
# ### **4.1. Usando diagramas de cajas**
# ---
#
# En este ejercicio deberá representar gráficamente la distribución y medidas de posición del número de reseñas positivas de cada título respecto a su valoración utilizando un **diagramas de cajas** como se presenta a continuación:
#
# > Para la imagen de referencia utilizamos el *colormap* **`afmhot`** como paleta de color.
#
# Almacene el resultado de la función de visualización en la variable **`reseñas_cajas`**.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pistas</b></font>
# </summary>
#
#
# * Al construir el diagrama de cajas puede seleccionar una variable categórica en el eje *x* para conocer las distribuciones de cada grupo independientemente.
# * Deberá agregar el título y etiquetas de los ejes por su cuenta. Para esto, utilice métodos de objetos **`Axes`** de *Matplotlib* como **`set_title`** y **`set_xlabel`** sobre el objeto **`reseñas_cajas`**.
# * Las cadenas de texto exactas usadas en este ejercicio son:
#   * **Título**: `'Numero de reseñas postivas vs valoración'`
#   * **Etiqueta del eje X**: `'valoración'`
#   * **Etiqueta del eje Y**: `'# comentarios positivos'`

# %%
### ESCRIBA SU CÓDIGO AQUÍ ### (~ 4-5 líneas de código)
reseñas_cajas = sns.boxplot(data=games,x='rating',y='positive_ratio', palette='afmhot')
reseñas_cajas.set_title('Numero de reseñas positivas vs valoración')
reseñas_cajas.set_xlabel('valoración')
reseñas_cajas.set_ylabel('# comentarios positivos')
### FIN DEL CÓDIGO ###
reseñas_cajas
# Out:
# /tmp/ipython-input-4218753834.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   reseñas_cajas = sns.boxplot(data=games,x='rating',y='positive_ratio', palette='afmhot')
# <Axes: title={'center': 'Numero de reseñas positivas vs valoración'}, xlabel='valoración', ylabel='# comentarios positivos'>

# %% [markdown]
# **Salida esperada:**
#
# <img src = "https://drive.google.com/uc?export=view&id=1PVru_gygCRHEmVQy2Ooi5EohHRNzbpqW" alt = "Encabezado MLDS" width = "70%">  </img>

# %%
# NO ELIMINAR - NECESARIO PARA LA CORRECTA CALIFICACIÓN
reseñas_cajas.get_figure().show()
plt.close()

# %% [markdown]
# ### **Evaluar código**

# %%
grader.run_test("Test 4_1_1", globals())
# Out:
# Test 4_1_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 4_1_2", globals())
# Out:
# Test 4_1_2
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %% [markdown]
# ### **4.2. Usando gráficas de enjambre**
# ---
#
# En este ejercicio deberá representar gráficamente la distribución y medidas de posición del número de reseñas positivas de cada título respecto a su valoración utilizando
#  una **gráfica de enjambre o *swarm plot***, además, deberá considerar las plataformas, así:
#
# > * La paleta de colores usada para la imagen de referencia es **`Set1`**.
# * El radio de los puntos es de $2$ unidades.
#
#
# Almacene el resultado de la función de visualización en la variable **`clase_swarm`**.
#
# **Nota:** Por complejidad computacional, diesme el conjutno de datos en un fatcor de 100, asi:  `games[::100]`

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pistas</b></font>
# </summary>
#
# * Use la función **`swarmplot`** de *Seaborn* para generar el diagrama de enjambre.
# * En esta gráfica las categorías (windows, mac, linux) deben estar bien diferenciadas entre sí. Use el parámetro **`dodge`** para conseguirlo.
# * Si el anterior punto es correcto, debería usar los mismos nombres de variables.
# * Configure el tono del color de acuerdo al valor de la variable categórica **`platform`**.
# * Deberá agregar el título y etiquetas de los ejes por su cuenta. Para esto, utilice métodos de objetos **`Axes`** de *Matplotlib* como **`set_title`** y **`set_xlabel`** sobre el objeto **`reseñas_swarm`**.
# * Las cadenas de texto exactas usadas en este ejercicio son:
#   * **Título**: `'Numero de reseñas postivas vs valoración'`
#   * **Etiqueta del eje X**: `'valoración'`
#   * **Etiqueta del eje Y**: `'# comentarios positivos'`

# %%
### ESCRIBA SU CÓDIGO AQUÍ ### (~ 4-5 líneas de código)
clase_swarm = sns.swarmplot(data=games[::100],x='rating', y='positive_ratio',hue='platform', palette='Set1',dodge=True,size=2)
clase_swarm.set_title('Numero de reseñas postivas vs valoración')
clase_swarm.set_xlabel('valoración')
clase_swarm.set_ylabel('# comentarios positivos')### FIN DEL CÓDIGO ###
clase_swarm
# Out:
# <Axes: title={'center': 'Numero de reseñas postivas vs valoración'}, xlabel='valoración', ylabel='# comentarios positivos'>

# %% [markdown]
# **Salida esperada:**
#
# <img src = "https://drive.google.com/uc?export=view&id=19SygkCJrqpisT1q6rrj__7lQvs2VOk_g" alt = "Encabezado MLDS" width = "70%">  </img>

# %%
# NO ELIMINAR - NECESARIO PARA LA CORRECTA CALIFICACIÓN
clase_swarm.get_figure().show()
plt.close()

# %% [markdown]
# ### **Evaluar código**

# %%
grader.run_test("Test 4_2_1", globals())
# Out:
# Test 4_2_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 4_2_2", globals())
# Out:
# Test 4_2_2
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %% [markdown]
# ## **Evaluación**
# **¡Felicitaciones!** Ha terminado la tarea de la Unidad 4. ¡Excelente trabajo!

# %%
# grader.submit_task(globals())
# Out:
# Test 1_1
# Test 1_2
# Test 2_1_1
# Test 2_1_2
# Test 2_2_1
# Test 2_2_2
# Test 3_1_1
# Test 3_1_2
# Test 3_2_1
# Test 3_2_1
# Test 4_1_1
# Test 4_1_2
# Test 4_2_1
# Test 4_2_2
# <h3>Grading succeeded</h3>
# <h6 style="color: green;">TEST Test 1_1 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 1_2 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 2_1_1 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 2_1_2 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 2_2_1 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 2_2_2 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 3_1_1 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# ...

# %% [markdown]
# ## **Créditos**
# ---
#
# * **Profesor:** [Felipe Restrepo Calle](https://dis.unal.edu.co/~ferestrepoca/)
# * **Asistentes docentes:**
#   - Juan Sebastian Malagón Torres
#
# **Universidad Nacional de Colombia** - *Facultad de Ingeniería*
